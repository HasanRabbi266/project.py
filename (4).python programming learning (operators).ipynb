# %% [markdown]
# python divides the operators in the following categories-
#
# (1)arithmetic operators
# (2)identity operators
# (3)bitwise operators
# (4)comparison operators
# (5)logical operators
# (6)assignment operators
# (7)membership operators

# %% [markdown]
# python arithmetic operators:

# %%
#assingning the variables
x=15
y=4
z=3

# %%
x+y
# Out:
# 19

# %%
x-y
# Out:
# 11

# %%
x/y
# Out:
# 3.75

# %%
x*y
# Out:
# 60

# %%
#exponentiation
2*2
# Out:
# 4

# %%
2**2
# Out:
# 4

# %%
x**y #15*15*15*15*
# Out:
# 50625

# %%
#floor  division (value is taken only int or the number which is infront of decimal point
x//y
# Out:
# 3

# %%
import math
math.floor(x/y)
# Out:
# 3

# %%
math.ceil(x/y)
# Out:
# 4

# %% [markdown]
# python identity operators:

# %%
x = 10 
y=10
x is y
# Out:
# True

# %%
x == y #comparison operator and values are same;so true
# Out:
# True

# %%
x = 100017
y=x
z=100017

# %%
x is y #memory addresses are same;so true
# Out:
# True

# %%
x is z values same but memory addresses are not same;so false.
# Out:
# False

# %%
id(x)
# Out:
# 1369564090672

# %%
id(y) #for this, x is y. is and is not are identity operator.it is considered when the variable's values are in the same memory address.
# Out:
# 1369564090672

# %%
id(z) #for this,x is not z in spite of having same value.  it is called (x==y)
# Out:
# 1369564091216

# %%
x==z
# Out:
# True

# %%
x is not z
# Out:
# True

# %% [markdown]
# python membership operator:

# %%
list1 = [1,2,3,4,5,6]
1 in list1
# Out:
# True

# %%
10 in list1
# Out:
# False

# %%
10 not in list1
# Out:
# True

# %%
set={1,2,3,4}
2 in set
# Out:
# True

# %%
string='data science'
'data' in string
# Out:
# True

# %% [markdown]
# bitwise operator:

# %%
x = 1010 #10 ;1011,1100,1101,1110,1111
y = 0101 #5

x | y =1111
x & y =0000
# Out:
#   Cell In[4], line 2
#     y = 0101 #5
#         ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
x = 10
y = 5
x | y
# Out:
# 15

# %%
x & y
# Out:
# 0

# %% [markdown]
# python comparison data type :

# %%
10 == 10
# Out:
# True

# %%
10 > 10
# Out:
# False

# %%
10>=10
# Out:
# True

# %% [markdown]
# python logical operators:

# %%
10 > 4 and 10 < 3
# Out:
# False

# %%
10 > 4 or 10 < 3
# Out:
# True

# %%
not(10 > 4 and 10 < 3)
# Out:
# True

# %%
not (10 > 4 or 10 < 3)
# Out:
# False

# %% [markdown]
# python assignment operators:

# %%
x = 10
x += 4

# %%
x
# Out:
# 14

# %%
x =x+4

# %%
x
# Out:
# 18
