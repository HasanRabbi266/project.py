# %%
'data science'#shift+enter=run
# Out:
# 'data science'

# %% [markdown]
# Input & Output Function

# %%
print('hello world,welcome to learning python') #we need to use quotation mark in the print function for strings. (shift+tab=string methods)
# Out:
# hello world,welcome to learning python

# %%
print('hello world', 'welcome to learning python',sep=' & ',end='*')#must use comma to separate data
# Out:
# hello world & welcome to learning python*

# %% [markdown]
# Variable

# %%
var='hasan rabbi'#variable
print(var)

# %%
print('my name is '+var)#use quotation marks in the print function if it is a string but not if it is a  variable. (string+variable)
# Out:
# my name is hasan rabbi

# %%
id(var)
# Out:
# 2632939713840

# %%
import sys
sys.getsizeof(var)
# Out:
# 52

# %%
x=100
x #we don't need to use print function in jupyter notebook.
# Out:
# 100

# %%
y=100
y
# Out:
# 100

# %%
id(x) #it indicates where this data is saved.
# Out:
# 140713209049096

# %%
id(y) #as the values of x and y are same and so the address is same.
# Out:
# 140713209049096

# %%
x=1000 #it shows same address until 3 digit.inspite of being same value,the addresses are different because the values are 4 digit.
y=1000
id(x)
# Out:
# 1587186858256

# %%
id(y)
# Out:
# 1587186858128

# %%
x,y,z=10,100,1000 #you can write many variables together in this IDE

# %%
x
# Out:
# 10

# %%
y
# Out:
# 100

# %%
z
# Out:
# 1000

# %%
#variables are case sensitive

# %%
# 3 types:
#(1)camelCaseBar
#(@)PascalCaseBar
#(3)snake_case_bar

# %%
# there are two types of variable : (1)Global variable,(2)Local variable
