# %% [markdown]
# input function

# %%
data='data science fun'

# %%
type(data)
# Out:
# str

# %%
data=input() #input function takes value as a string
# Out:
#  data science fun!

# %%
data
# Out:
# 'data science fun!'

# %%
type(data) #input function takes value as a string
# Out:
# str

# %%
x=input()
# Out:
#  10

# %%
y=input()
# Out:
#  20

# %%
x+y #as values are taken as string
# Out:
# '1020'

# %%
type(x+y)
# Out:
# str

# %%
x=int(x)#convert to integer from string

# %%
x
# Out:
# 10

# %%
y=int(y)
y
# Out:
# 20

# %%
x+y
# Out:
# 30

# %%
type(x+y)
# Out:
# int

# %%
x=int(input('enter your 1st number:'))
# Out:
# enter your 1st number: 200

# %%
y=int(input('enter your 2nd number:'))
# Out:
# enter your 2nd number: 10.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 y=int(input('enter your 2nd number:'))
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
y=float(input('enter your 2nd number:'))
# Out:
# enter your 2nd number: 10.5

# %%
x+y
# Out:
# 210.5

# %%
type(x+y)
# Out:
# float

# %%
data='60 days of python'

# %%
type(data)
# Out:
# str

# %%
len(data) #lenth of value and a gap also ben counted
# Out:
# 17

# %%
import sys
sys.getsizeof(data)
# Out:
# 58

# %%
data.count('python')
# Out:
# 1

# %%
sub='days of'
data.count(sub)
# Out:
# 1

# %%
data.find('of')
# Out:
# 8

# %%
data.find('f')
# Out:
# 9

# %%
data.find('y',6,10)#not exist
# Out:
# -1

# %%
data.find('y',6,14)
# Out:
# 12

# %%
data.index('y')
# Out:
# 5

# %%
data.index('y',6,13)
# Out:
# 12

# %%
data.index(ai)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 data.index(ai)
#
# NameError: name 'ai' is not defined

# %%
data.lower()#convert all char  into lower case
# Out:
# '60 days of python'

# %%
data.upper()#convert all char into upper case
# Out:
# '60 DAYS OF PYTHON'

# %%
data.casefold()#lower
# Out:
# '60 days of python'

# %%
x='data SCIENCE is fun!'
x.capitalize()#convert only 1st char into upper case
# Out:
# 'Data science is fun!'

# %%
x.swapcase() #convert all lower char into upper
# Out:
# 'DATA science IS FUN!'

# %%
x.title()
# Out:
# 'Data Science Is Fun!'

# %%
x.islower()
# Out:
# False

# %%
x.isupper()
# Out:
# False

# %%
x.upper()
# Out:
# 'DATA SCIENCE IS FUN!'

# %%
x.isupper()
# Out:
# False

# %%
x.isdigit()
# Out:
# False

# %%
x.encode()
# Out:
# b'data SCIENCE is fun!'

# %%
type(x.encode())
# Out:
# bytes

# %%
x
# Out:
# 'data SCIENCE is fun!'

# %%
x.split()
# Out:
# ['data', 'SCIENCE', 'is', 'fun!']

# %%
x.split()[0]
# Out:
# 'data'

# %%
x.split()[1]
# Out:
# 'SCIENCE'

# %%
x.center(100)
# Out:
# '                                        data SCIENCE is fun!                                        '

# %%
x.replace('data','AI')
# Out:
# 'AI SCIENCE is fun!'

# %%
x=10
y=100
z=x*y

# %%
z
# Out:
# 1000

# %%
print('i have',z,'taka')
# Out:
# i have 1000 taka

# %%
print('i have {} taka'.format(z))
# Out:
# i have 1000 taka
