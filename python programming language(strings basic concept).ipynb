# %% [markdown]
# String

# %%
data="data science fun" #the data which we write inside double quotation called string

# %%
type(data) #this function is used to identify data types
# Out:
# str

# %%
data=input()
# Out:
#  data science fun

# %%
data
# Out:
# 'data science fun'

# %%
type(data)
# Out:
# str

# %%
x=input()
y=input()
# Out:
#  10
#  20

# %%
x+y #input function understand all the data as string (default)
# Out:
# '1020'

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# str

# %%
x=int (x)
y=int(y)

# %%
x+y
# Out:
# 30

# %%
x=int(input("Enter your 1st number: "))
# Out:
# Enter your 1st number:  100

# %%
y=float(input("Enter your2nd number: "))
# Out:
# Enter your2nd number:  10.5

# %%
x+y # we can use different types of data by writting in this system by using input function
# Out:
# 110.5

# %%
h=input("my name is")
# Out:
# my name is Hasan Rabbi

# %%
h
# Out:
# 'Hasan Rabbi'

# %%
data ="python course"

# %%
type(data)
# Out:
# str

# %%
len(data) # this function is used to share how many word the main string has and it's length where a space is considered & valued 1.
# Out:
# 13

# %%
import sys # express memory space which is occupied by main string
sys.getsizeof(data) #54 bytes
# Out:
# 54

# %% [markdown]
# Sub String

# %%
data.count("python") #this line is about sub string .here it means there is 1 python word as sub string inside main string where variable is (data).
# Out:
# 1

# %%
sub = "course"

# %%
data.count(sub)
# Out:
# 1
